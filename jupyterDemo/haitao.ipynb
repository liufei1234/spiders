# %%
import requests
from bs4 import BeautifulSoup
import urllib2


# print soup.get_text()
# print soup.title.parent.string
# print '====='
# print soup.title.string
# print '====='
# print soup.title.name
# print '===='
# print soup.title
# print '========'
# print soup.prettify()

header = {
    'User-Agent':'Mozilla/5.0 (iPhone; CPU iPhone OS 9_1 like Mac OS X) AppleWebKit/601.1.46 (KHTML, like Gecko) Version/9.0 Mobile/13B143 Safari/601.1'
}
r = requests.post('https://m.55haitao.com',headers=header)
r.encoding = 'utf-8'
ref = BeautifulSoup(r.text,'html.parser')


for item in ref.select('#new_deal_ul li'):
    print ' name      :' + item.select('.store-name')[0].text,\
          '\n content :' + item.select('h1')[0].text,\
          '\n price   :' + item.select('.real-price')[0].text,\
          '\n discount:' + item.select('.preferential')[0].text,\
          '\n url     :'+item.a['href'],\
          '\n img     :' +item.a.div.img['data-original'],\
          '\n=========================================================='
# Out:
#  name      :BabyHaven
#  content :【最高立减5美元+免邮】Ddrops 婴儿维生素D3滴剂 90滴
#  price   :$14.99（约104元）
#  discount:返2%
#  url     :/deals/335385.html
#  img     :https://cdn.55haitao.com/bbs/data/attachment/deal/2017/10/09/641c3525adb42b757ec4516c4c6321a9554.jpg@0e_240w_240h_1l_0i_0o_90Q_1x
# ==========================================================
#  name      :Feelunique中文官网
#  content :Feelunique中文官网：Charlotte Tilbury 哑光丝绒唇膏等
#  price   :满£88立减£8！
#  discount:最高返5%
#  url     :/deals/335384.html
#  img     :https://cdn.55haitao.com/bbs/data/attachment/deal/2017/07/05/e97821bd47833696713b538073e6c497.jpg@0e_240w_240h_1l_0i_0o_90Q_1x
# ==========================================================
#  name      :亚马逊海外购
#  content :大码福利！【亚马逊海外购】Skins 思金斯 男士 A400梯度压缩裤七分裤
#  price   :到手价383元
#  discount:最高返3.5%
#  url     :/deals/335383.html
#  img     :https://cdn.55haitao.com/bbs/data/attachment/deal/2017/10/09/620d447a46d918a954f65e94088c4fc5029.jpg@0e_240w_240h_1l_0i_0o_90Q_1x
# ==========================================================
#  name      :The Dreslyn
#  content :【75折收加拿大鹅！】The Dreslyn 官网：全场服饰鞋包 包括川保久玲、加拿大鹅、GGDB 等品牌
#  price   :最高享7.5折
#  discount:返3%
#  url     :/deals/335235.html
#  img     :https://cdn.55haitao.com/bbs/data/attachment/deal/2017/09/08/57802ff7484ab53a7b9aca8c1b6e72f09fb.jpg@0e_240w_240h_1l_0i_0o_90Q_1x
# ==========================================================
#  name      :Michael Kors
#  content :MICHAEL Michael Kors Jet Set Travel 大号女士斜挎包
#  price   :$88.8（约615元）
#  discount:返6%
#  url     :/deals/335310.html
#  img     :https://cdn.55haitao.com/bbs/data/attachment/deal/2017/10/09/5789445659508c6378a7dd7f04f0c2beb33.jpg@0e_240w_240h_1l_0i_0o_90Q_1x
# ==========================================================
#  name      :eBay
#  content :史低价！Raymond Weil Toccata 男士真皮表带腕表 5488-STC 多色可选
#  price   :$228.99（约1,585元）
#  discount:最高返1%
#  url     :/deals/335338.html
#  img     :https://cdn.55haitao.com/bbs/data/attachment/deal/2017/10/09/57825d9b018dc4a3c02ebf86547e9a7cb3d.png@0e_240w_240h_1l_0i_0o_90Q_1x
# ==========================================================
#  name      :Urban Outfitters US
#  content :【限尺码！】Puma 彪马 Basket Heart Metallic Safari 女士蝴蝶结运动鞋
#  price   :$35.99（约249元）
#  discount:返4%
#  url     :/deals/335341.html
#  img     :https://cdn.55haitao.com/bbs/data/attachment/deal/2017/10/09/578d30a9f6a2e646b443cc39630cedce401.png@0e_240w_240h_1l_0i_0o_90Q_1x
# ==========================================================
#  name      :Selfridges
#  content :Charlotte Tilbury 圣诞限量迷你口红套装
#  price   :￡29（约259元）
#  discount:暂无返利
#  url     :/deals/335382.html
#  img     :https://cdn.55haitao.com/bbs/data/attachment/deal/2017/10/09/692b3b38e7ffc08f09b3fa9cf0399d94e09.jpg@0e_240w_240h_1l_0i_0o_90Q_1x
# ==========================================================
#  name      :PharmacyOnline中文网
#  content :【史低价】Blackmores 澳佳宝 维生素E面霜 冰冰霜 50g
#  price   :澳币6.95（约38元）
#  discount:最高返3.5%
#  url     :/deals/335380.html
#  img     :https://cdn.55haitao.com/bbs/data/attachment/deal/2017/10/09/6417629621d33d1befc0059faf56043ede2.jpg@0e_240w_240h_1l_0i_0o_90Q_1x
# ==========================================================
#  name      :SkinCareRx
#  content :SkinCareRx：FILORGA 菲洛嘉 十全大补面膜、360靓丽雕塑眼霜等护肤
#  price   :7折！
#  discount:返7%
#  url     :/deals/335379.html
#  img     :https://cdn.55haitao.com/bbs/data/attachment/deal/2017/09/06/611b4d73674c66c888714b0657d884e3320.jpg@0e_240w_240h_1l_0i_0o_90Q_1x
# ==========================================================
